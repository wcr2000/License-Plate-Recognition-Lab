# %% [markdown]
# # Basic Technical

# %%
import os
import glob
import shutil
import cv2
from ultralytics import YOLO

# Paths
INPUT_DIR = './finish'
CROP_DIR = './crop_finish'
SKIP_DIR = './skip_finish'

# Create output directories if they don't exist
os.makedirs(CROP_DIR, exist_ok=True)
os.makedirs(SKIP_DIR, exist_ok=True)

# Load your license plate detector model
yolo_det = YOLO('./models/yolo11_anpr_ghd.pt')

# Confidence threshold (0.0–1.0)
CONF_THRESH = 0.8

# Iterate over all JPGs in the input folder
for img_path in glob.glob(os.path.join(INPUT_DIR, '*.jpg')):
    img = cv2.imread(img_path)
    if img is None:
        continue

    # Run detection with confidence threshold
    results = yolo_det(img, conf=CONF_THRESH)

    # Collect all boxes with conf >= threshold
    boxes = []
    for res in results:
        for box, conf in zip(res.boxes.xyxy, res.boxes.conf):
            if conf >= CONF_THRESH:
                x1, y1, x2, y2 = map(int, box.cpu().numpy())
                boxes.append((x1, y1, x2, y2))

    base_name = os.path.splitext(os.path.basename(img_path))[0]
    if boxes:
        # Save each cropped plate
        for idx, (x1, y1, x2, y2) in enumerate(boxes, start=1):
            crop = img[y1:y2, x1:x2]
            out_path = os.path.join(CROP_DIR, f"{base_name}_plate{idx}.jpg")
            cv2.imwrite(out_path, crop)
    else:
        # No detections above threshold: move original to skip folder
        shutil.copy(img_path, os.path.join(SKIP_DIR, os.path.basename(img_path)))

print("Done processing all images.")
# Out:
# 0: 640x384 1 LicensePlate, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 28.9ms
# Speed: 1.0ms preprocess, 28.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 24.7ms
# Speed: 1.7ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 27.1ms
# Speed: 0.9ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 27.7ms
# Speed: 1.3ms preprocess, 27.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 106.9ms
# Speed: 1.8ms preprocess, 106.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 107.2ms
# Speed: 2.4ms preprocess, 107.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 65.7ms
# Speed: 13.5ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 33.6ms
# Speed: 1.3ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 27.4ms
# Speed: 1.0ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 28.9ms
# Speed: 1.3ms preprocess, 28.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 33.4ms
# Speed: 0.9ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 32.0ms
# Speed: 0.9ms preprocess, 32.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 31.0ms
# Speed: 0.9ms preprocess, 31.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 36.9ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 21.7ms
# Speed: 0.9ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 28.8ms
# Speed: 2.1ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 27.7ms
# Speed: 0.9ms preprocess, 27.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 29.5ms
# Speed: 0.9ms preprocess, 29.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 26.3ms
# Speed: 0.9ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 25.9ms
# Speed: 0.8ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.6ms
# Speed: 1.5ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.4ms
# Speed: 1.4ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 24.4ms
# Speed: 0.8ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 20.7ms
# Speed: 0.9ms preprocess, 20.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 20.6ms
# Speed: 0.9ms preprocess, 20.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 21.9ms
# Speed: 0.9ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.3ms
# Speed: 0.9ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.0ms
# Speed: 0.8ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 24.9ms
# Speed: 0.9ms preprocess, 24.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 21.9ms
# Speed: 0.8ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.0ms
# Speed: 0.8ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.4ms
# Speed: 0.8ms preprocess, 23.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.0ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 24.4ms
# Speed: 0.9ms preprocess, 24.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 LicensePlate, 22.2ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Done processing all images.

# %% [markdown]
# # Filter technical

# %%
import os
import glob
import shutil
import cv2
import numpy as np
from ultralytics import YOLO
import math

# --- Paths & Params ---
INPUT_DIR    = './s3'
CROP_DIR     = './crop_image'
SKIP_DIR     = './skip_crop_image'
CONF_THRESH  = 0.8     # YOLO confidence threshold
FLAT_SIGMA   = 15      # sigma for flat-field
DENOISE_H    = 3       # h parameter for NLMeans
TEMPLATE_SZ  = (7,7)   # (templateWindowSize, searchWindowSize)

# Create output folders if needed
os.makedirs(CROP_DIR, exist_ok=True)
os.makedirs(SKIP_DIR, exist_ok=True)

# Load detector
yolo_det = YOLO('./models/license_plate_detector.pt')

# flat‐field function
def imflatfield(I, sigma):
    A = I.astype(np.float32) / 255.0
    Ihsv = cv2.cvtColor(A, cv2.COLOR_BGR2HSV)
    V = Ihsv[:, :, 2]
    filterSize = int(2 * np.ceil(2 * sigma) + 1)
    shading = cv2.GaussianBlur(V, (filterSize, filterSize), sigma, borderType=cv2.BORDER_REFLECT)
    meanV = np.mean(V)
    shading = np.maximum(shading, 1e-6)
    Vcorr = V * meanV / shading
    Ihsv[:, :, 2] = Vcorr
    B = cv2.cvtColor(Ihsv, cv2.COLOR_HSV2BGR)
    return np.round(np.clip(B * 255, 0, 255)).astype(np.uint8)

# Process each image
for img_path in glob.glob(os.path.join(INPUT_DIR, '*.jpg')):
    img = cv2.imread(img_path)
    if img is None:
        continue

    # 1. Detect plates
    results = yolo_det(img, conf=CONF_THRESH)[0]
    boxes = []
    for box, conf in zip(results.boxes.xyxy, results.boxes.conf):
        if conf >= CONF_THRESH:
            x1, y1, x2, y2 = map(int, box.cpu().numpy())
            boxes.append((x1, y1, x2, y2))

    base = os.path.splitext(os.path.basename(img_path))[0]
    if not boxes:
        # no plate → move to skip
        shutil.copy(img_path, os.path.join(SKIP_DIR, os.path.basename(img_path)))
        print(f"✖ {base}: no plate found, moved to skip.")
        continue

    # 2. For each detected plate: crop + flatfield + denoise + save
    for idx, (x1, y1, x2, y2) in enumerate(boxes, start=1):
        crop = img[y1:y2, x1:x2]
        # flat-field correction
        flat = imflatfield(crop, FLAT_SIGMA)
        # NLMeans denoise (color)
        denoised = cv2.fastNlMeansDenoisingColored(
            flat, None,
            h=DENOISE_H, hColor=DENOISE_H,
            templateWindowSize=TEMPLATE_SZ[0],
            searchWindowSize=TEMPLATE_SZ[1]
        )
        # save
        out_name = f"{base}_plate{idx}.jpg"
        cv2.imwrite(os.path.join(CROP_DIR, out_name), denoised)
        print(f"✔ {base}_plate{idx}: cropped & preprocessed.")

print("Done processing all images.")
# Out:
# 0: 640x384 (no detections), 38.7ms
# Speed: 2.6ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744089859416: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 24.0ms
# Speed: 2.2ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741078372064: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743477981295: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 20.7ms
# Speed: 0.8ms preprocess, 20.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743719542977: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 34.6ms
# Speed: 0.8ms preprocess, 34.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744380514801: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 20.2ms
# Speed: 0.8ms preprocess, 20.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1743754789356_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741307664248_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 31.4ms
# Speed: 0.9ms preprocess, 31.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1745126669368: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744117338153: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 26.0ms
# Speed: 0.9ms preprocess, 26.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744355121328: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743392689989: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743682038357: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742721203234: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743741958834: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.2ms
# Speed: 0.8ms preprocess, 21.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741521179864: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.0ms
# Speed: 0.8ms preprocess, 21.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741139733526: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.5ms
# Speed: 0.9ms preprocess, 21.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741561106940: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 20.3ms
# Speed: 0.8ms preprocess, 20.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1745374273215: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 21.7ms
# Speed: 0.8ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1744120267617_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 21.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743224354771: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.2ms
# Speed: 0.8ms preprocess, 21.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1740887338287: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 19.7ms
# Speed: 0.8ms preprocess, 19.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743899629270: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 20.1ms
# Speed: 0.8ms preprocess, 20.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1745400081000: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 20.3ms
# Speed: 0.8ms preprocess, 20.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743225147488: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 19.5ms
# Speed: 0.9ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744791716589: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 20.9ms
# Speed: 0.9ms preprocess, 20.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744237728207: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 19.9ms
# Speed: 0.9ms preprocess, 19.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1745377649148_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 26.5ms
# Speed: 1.2ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1742375785139_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 26.9ms
# Speed: 0.9ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1744713235519_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 28.5ms
# Speed: 1.0ms preprocess, 28.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744405871036: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742820305492: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 28.0ms
# Speed: 0.9ms preprocess, 28.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744443383971: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 26.8ms
# Speed: 1.1ms preprocess, 26.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1745565842515_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1731432619043: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1742301983166_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 31.3ms
# Speed: 1.2ms preprocess, 31.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741676245716_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1731631956006: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 22.8ms
# Speed: 0.9ms preprocess, 22.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742030307079: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 23.2ms
# Speed: 0.9ms preprocess, 23.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743939749203: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741306473300_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 24.8ms
# Speed: 0.9ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1745211464160: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 26.0ms
# Speed: 1.3ms preprocess, 26.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1
no plate found, moved to skip.
#
# 0: 640x384 (no detections), 23.2ms
# Speed: 0.9ms preprocess, 23.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743227251383: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 22.4ms
# Speed: 0.9ms preprocess, 22.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741493062707_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 23.5ms
# Speed: 0.9ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742189839147: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 21.8ms
# Speed: 1.0ms preprocess, 21.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1745819518347_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 26.2ms
# Speed: 0.9ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1743643368320_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 70.2ms
# Speed: 1.0ms preprocess, 70.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1744079973287_plate1: cropped & preprocessed.
#
# 0: 640x384 1 license_plate, 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1742185789612_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1733783741583: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744081761432: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 34.9ms
# Speed: 0.9ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741226251890_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 24.5ms
# Speed: 0.9ms preprocess, 24.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741318625745: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1731730881776: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 25.3ms
# Speed: 1.3ms preprocess, 25.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743472897581: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 26.7ms
# Speed: 1.1ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744805685162: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1740964659173_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 33.5ms
# Speed: 1.2ms preprocess, 33.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744429216314: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1732530432530: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744934530212: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1733942197772: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742298087530: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 28.9ms
# Speed: 0.9ms preprocess, 28.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744926745430: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.3ms
# Speed: 0.8ms preprocess, 21.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1745215138847: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 33.0ms
# Speed: 0.9ms preprocess, 33.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742767259549: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 27.0ms
# Speed: 0.9ms preprocess, 27.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1732845283003_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742316856414: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 37.3ms
# Speed: 0.9ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1743291045779_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 34.1ms
# Speed: 0.9ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741277167324: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743479198341: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 26.8ms
# Speed: 1.3ms preprocess, 26.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742437996371: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743224931736: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1740740117132: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 33.8ms
# Speed: 2.0ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743225944080: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1741399693294_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 68.6ms
# Speed: 6.8ms preprocess, 68.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1742023450298: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1741661402207: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 68.6ms
# Speed: 2.2ms preprocess, 68.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744203869611: no plate found, moved to skip.
#
# 0: 640x384 1 license_plate, 25.1ms
# Speed: 0.9ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# ✔ 1743391270338_plate1: cropped & preprocessed.
#
# 0: 640x384 (no detections), 32.2ms
# Speed: 1.1ms preprocess, 32.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1744617197912: no plate found, moved to skip.
#
# 0: 640x384 (no detections), 21.8ms
# Speed: 1.0ms preprocess, 21.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# ✖ 1743490459171: no plate found, moved to skip.
# Done processing all images.

# %% [markdown]
# # Plate Straight

# %%
import pandas as pd
df = pd.read_csv('test.txt', sep=',', encoding='utf-8-sig')
df['file_name']     = './crop_image/' + df['file_name']
df['expected_full'] = df['no'] + df['province']
